# %%
import pandas as pd

# %%
populationDf = pd.read_excel('input/DDW-0000C-08.xlsx', names=['table','State Code','distCode','Name','TRU','agegroup','totalP','totalM','totalF','illitP','illitM','illitF','litP','litM','litF','litWoEdP','litWoEdM','litWoEdF','blwPriP','blwPriM','blwPriF','priP','priM','priF','midP','midM','midF','matrcP','matrcM','matrcF','highSecP','highSecM','highSecF','dipNTP','dipNTM','dipNTF','dipTP','dipTM','dipTF','gradP','gradM','gradF','unclassP','unclassM','unclassF','blank'])
populationDf.head(20)
# Out:
#     table State Code distCode       Name     TRU   agegroup      totalP  \
# 0   Table      State   Distt.  Area Name  Total/  Age-group       Total
# 1    Name       Code     Code        NaN  Rural/        NaN         NaN
# 2     NaN        NaN      NaN        NaN  Urban/        NaN         NaN
# 3     NaN        NaN      NaN        NaN     NaN        NaN     Persons
# 4     NaN        NaN      NaN        NaN     NaN          1           2
# 5     NaN        NaN      NaN        NaN     NaN        NaN         NaN
# 6   C2308         00      000      INDIA   Total   All ages  1210854977
# 7   C2308         00      000      INDIA   Total        0-6   164515253
# 8   C2308         00      000      INDIA   Total          7    24826640
# 9   C2308         00      000      INDIA   Total          8    26968373
# 10  C2308         00      000      INDIA   Total          9    23424638
# 11  C2308         00      000      INDIA   Total         10    30552107
# 12  C2308         00      000      INDIA   Total         11    24740946
# 13  C2308         00      000      INDIA   Total         12    27877307
# 14  C2308         00      000      INDIA   Total         13    24280683
# 15  C2308         00      000      INDIA   Total         14    25258169
# 16  C2308         00      000      INDIA   Total         15    25899454
# 17  C2308         00      000      INDIA   Total         16    24592293
# 18  C2308         00      000      INDIA   Total         17    21217467
# 19  C2308         00      000      INDIA   Total         18    27958147
#
#        totalM     totalF      illitP  ...                             dipTP  \
# 0         NaN        NaN  Illiterate  ...                               NaN
# 1         NaN        NaN         NaN  ...  Technical diploma or certificate
# 2         NaN        NaN         NaN  ...              not equal to degree
# 3       Males    Females     Persons  ...                           Persons
# 4           3          4           5  ...                                32
# 5         NaN        NaN         NaN  ...                               NaN
# 6   623270258  587584719   447216165  ...                           7238719
# 7    85752254   78762999   164515253  ...                                 0
# 8    12903364   11923276     6748214  ...                                 0
# 9    14061937   12906436     4131414  ...                                 0
# 10   12214985   11209653     2491904  ...                                 0
# 11   16089436   14462671     3454505  ...                                 0
# 12   12962604   11778342     1988473  ...                                 0
# 13   14637892   13239415     2391529  ...                                 0
# 14   12563775   11716908     1810476  ...                                 0
# 15   13165128   12093041     2100785  ...                                 0
# 16   13739746   12159708     2599957  ...                                 0
# 17   13027935   11564358     2512487  ...                                 0
# 18   11349449    9868018     2038455  ...                                 0
# 19   15020851   12937296     3727975  ...                            374081
#
#       dipTM    dipTF             gradP     gradM     gradF      unclassP  \
# 0       NaN      NaN               NaN       NaN       NaN           NaN
# 1       NaN      NaN  Graduate & above       NaN       NaN  Unclassified
# 2       NaN      NaN               NaN       NaN       NaN           NaN
# 3     Males  Females           Persons     Males   Females       Persons
# 4        33       34                35        36        37            38
# 5       NaN      NaN               NaN       NaN       NaN           NaN
# 6   5354161  1884558          68288971  42120460  26168511       3031570
# 7         0        0                 0         0         0             0
# 8         0        0                 0         0         0        136465
# 9         0        0                 0         0         0         96524
# 10        0        0                 0         0         0         70452
# 11        0        0                 0         0         0         85652
# 12        0        0                 0         0         0         65030
# 13        0        0                 0         0         0         68452
# 14        0        0                 0         0         0         56720
# 15        0        0                 0         0         0         58561
# 16        0        0                 0         0         0         62039
# 17        0        0                 0         0         0         60587
# 18        0        0                 0         0         0         53520
# 19   271491   102590                 0         0         0         69648
#
#    unclassM unclassF blank
# 0       NaN      NaN   NaN
# 1       NaN      NaN   NaN
# 2       NaN      NaN   NaN
# 3     Males  Females   NaN
# 4        39       40   NaN
# 5       NaN      NaN   NaN
# 6   1647116  1384454   NaN
# 7         0        0   NaN
# 8     75715    60750   NaN
# 9     52561    43963   NaN
# 10    38456    31996   NaN
# 11    47423    38229   NaN
# 12    35877    29153   NaN
# 13    37773    30679   NaN
# 14    30680    26040   NaN
# 15    31901    26660   NaN
# 16    34656    27383   NaN
# 17    33777    26810   NaN
# 18    30035    23485   NaN
# 19    39697    29951   NaN
#
# [20 rows x 46 columns]

# %%
populationDf = populationDf.iloc[6:, : ]
populationDf = populationDf.astype({'State Code':int})
populationDf = populationDf[populationDf['TRU']=='Total']
populationDf = populationDf[populationDf['agegroup']=='All ages']
populationDf = populationDf[['State Code','Name','blwPriM','blwPriF','priM','priF','midM','midF','matrcM','matrcF','highSecM','highSecF','dipNTM','dipNTF','dipTM','dipTF','gradM','gradF']]
populationDf
# Out:
#       State Code                               Name   blwPriM   blwPriF  \
# 6              0                              INDIA  78445099  68452498
# 93             1            State - JAMMU & KASHMIR    541130    446644
# 180            2           State - HIMACHAL PRADESH    326058    285417
# 267            3                     State - PUNJAB   1273936    953748
# 354            4                 State - CHANDIGARH     51211     39658
# 441            5                State - UTTARAKHAND    554430    480153
# 528            6                    State - HARYANA   1403012   1070133
# 615            7               State - NCT OF DELHI    796975    661086
# 702            8                  State - RAJASTHAN   4423518   3660309
# 789            9              State - UTTAR PRADESH  11763367   9661113
# 876           10                      State - BIHAR   7308358   6393622
# 963           11                     State - SIKKIM     66658     49442
# 1050          12          State - ARUNACHAL PRADESH     88788     76188
# 1137          13                   State - NAGALAND    134218    124376
# 1224          14                    State - MANIPUR    123662    119904
# 1311          15                    State - MIZORAM    105262    110603
# 1398          16                    State - TRIPURA    363853    361608
# 1485          17                  State - MEGHALAYA    311818    297246
# 1572          18                      State - ASSAM   2469904   2080535
# 1659          19                State - WEST BENGAL   8437465   7465147
# 1746          20                  State - JHARKHAND   2292684   2000731
# 1833          21                     State - ODISHA   3126770   2759801
# 1920          22               State - CHHATTISGARH   2011523   1675846
# 2007          23             State - MADHYA PRADESH   5242949   4339265
# 2094          24                    State - GUJARAT   4486708   3976121
# 2181          25                State - DAMAN & DIU     15332     11291
# 2268          26       State - DADRA & NAGAR HAVELI     24482     19227
# 2355          27                State - MAHARASHTRA   8069806   7266014
# 2442          28             State - ANDHRA PRADESH   3884076   3553443
# 2529          29                  State - KARNATAKA   3655942   3268127
# 2616          30                        State - GOA     80497     80806
# 2703          31                State - LAKSHADWEEP      4523      4887
# 2790          32                     State - KERALA   2076920   2324577
# 2877          33                 State - TAMIL NADU   2861589   2767790
# 2964          34                 State - PUDUCHERRY     45162     48024
# 3051          35  State - ANDAMAN & NICOBAR ISLANDS     22513     19616
#
#           priM      priF      midM      midF    matrcM    matrcF  highSecM  \
# 6     99311072  84859761  77629578  56273688  63769834  42169909  46481321
# 93      719512    566397   1015129    651252    919672    492301    486800
# 180     576764    586231    452919    373692    666498    461499    368592
# 267    2273540   2014660   1747063   1319242   2472299   1714074   1313943
# 354      73645     56598     67964     43915     88021     54185     63200
# 441     803056    747518    806770    600101    627977    391513    444663
# 528    2075334   1696688   1557670   1147612   2064923   1161013   1199855
# 615    1197622   1033272   1099958    831453   1318133    868181    930296
# 702    6143552   4380872   4788350   2530873   3168905   1441280   1752886
# 789   15505178  12293614  14276668   8846060   9748121   5389194   6820583
# 876    7625383   5529586   4930890   3038709   4785058   2481070   2584078
# 963      62664     52937     37520     32025     31220     22048     20910
# 1050    102518     86851     82535     63313     65757     43547     46020
# 1137    170554    159804    164734    139877     96490     73035     59783
# 1224    164889    162064    251129    205903    185952    144264    125578
# 1311    108434     99016    104978     96504     46235     41918     36061
# 1398    363404    335252    320040    272356    117515     83314    163371
# 1485    203761    209168    151272    146625     86803     73260     67422
# 1572   2378849   2004541   2248173   2036838    802772    642743   1468893
# 1659   7897027   7057564   6684464   5789837   3151360   2279494   3253159
# 1746   2752242   2056362   1895039   1196068   1569270    904555    940065
# 1833   4157327   3557389   3035765   2249478   1885832   1331523   1050721
# 1920   2267581   1924563   1825488   1376916   1003394    625093    764504
# 2007   6640472   5237769   5094579   3336421   2819198   1622068   2098416
# 2094   5568559   4988442   4031450   2422485   3788353   2343644   1923817
# 2181     26048     15399     24792     10834     27874     11615     15227
# 2268     28803     19633     24919     12466     24529      9726     14623
# 2355   8346143   8282058   7132530   5460199   7914102   5645739   5609011
# 2442   6904114   6545186   3006742   2565412   4842743   3742738   3381495
# 2529   4944027   4549079   2869395   2292313   2784883   2297524   3574640
# 2616     94300     87195     91716     74807    102298     83080     98502
# 2703      6500      6313      5970      5335      3252      2523      4395
# 2790   2522296   2543414   2590783   2469026   1906020   1946369   2307363
# 2877   6479422   5845740   5087592   4520412   4540573   3652651   3405933
# 2964     89632     98091     85255     86046     87749     74077     68217
# 3051     37920     30495     39337     29283     26053     19051     18299
#
#       highSecF  dipNTM  dipNTF    dipTM    dipTF     gradM     gradF
# 6     31461272  726565  345724  5354161  1884558  42120460  26168511
# 93      289637    3542    1239    33854    16968    401279    252485
# 180     293865    4077    4442    37213    16200    251164    195445
# 267     996568   11117   13170   147801    86564    873776    887070
# 354      44399     510     996     9660     4141    104748     89705
# 441     310345    3102    1714    30072     6100    512068    398220
# 528     692258   17774   12840   143883    51232   1102809    774276
# 615     668139    6430    6108    61852    32734   1535972   1221872
# 702     762977    4801    2721   129531    35103   2086247    977035
# 789    3986422   73327   62631   167522    22347   6378138   3541700
# 876    1255317   58956   34095    30839     4627   2326092    735584
# 963      15212     103      52     1187      446     19290     13379
# 1050     28185     606     172     3573      821     36430     17176
# 1137     46601     323     286     3411     1523     53023     36695
# 1224     98999     452     153     3662     4309    135082     90538
# 1311     33008     103      89     1111      751     29527     20094
# 1398    109924     320      94     4781     1196     88621     49191
# 1485     59154     130      64     2189     1288     46311     44208
# 1572   1038345    3106     577    30143     6528    639241    372104
# 1659   2346794   15236    4891   120335    18190   3088673   1739144
# 1746    519621   14198    8468    55953     8915    906174    422303
# 1833    687564   28452    6202   157099    31169   1174184    609613
# 1920    407882    2728    1135    45165     6425    659081    359772
# 2007   1094806    6814    2918    85480    14358   2051127   1171675
# 2094   1229749   25992   11764   455161   206240   1891932   1282226
# 2181      7113     120      42     2226      771      8425      4377
# 2268      6906     275      69     3645     1103     12227      6947
# 2355   3679511   58561   24973   680370   177997   5167671   3471410
# 2442   2261515   72832   21666   587970   117304   3632622   1944765
# 2529   2725573  159259   46956   610709   182357   2489209   1554438
# 2616     80999    1160     796    24792    10802     74077     72751
# 2703      2783      77      35      551      302      1458       844
# 2790   2577719   34264   39593   508075   387113   1131336   1399985
# 2877   3023417  116345   33741  1143646   414880   3119342   2338400
# 2964     64733    1293     911    27765    11551     79482     62547
# 3051     15232     180     121     2935     2203     13622     10537

# %%
pDf = pd.DataFrame(columns=['state/ut','literacy-group','Males','Females'])
for stCode in range(36):
    stDf = populationDf[populationDf['State Code']==stCode]
    pDf.loc[len(pDf.index)] = [stCode,'Literate but below primary',stDf.iloc[0]['blwPriM'],stDf.iloc[0]['blwPriF']]
    pDf.loc[len(pDf.index)] = [stCode,'Primary but below middle',stDf.iloc[0]['priM'],stDf.iloc[0]['priF']]
    pDf.loc[len(pDf.index)] = [stCode,'Middle but below matric/secondary',stDf.iloc[0]['midM'],stDf.iloc[0]['midF']]
    pDf.loc[len(pDf.index)] = [stCode,'Matric/Secondary but below graduate',stDf.iloc[0]['matrcM']+stDf.iloc[0]['highSecM']+stDf.iloc[0]['dipNTM']+stDf.iloc[0]['dipTM'],stDf.iloc[0]['matrcF']+stDf.iloc[0]['highSecF']+stDf.iloc[0]['dipNTF']+stDf.iloc[0]['dipTF']]
    pDf.loc[len(pDf.index)] = [stCode,'Graduate and above',stDf.iloc[0]['gradM'],stDf.iloc[0]['gradF']]

pDf = pDf.reset_index(drop=True)
pDf
# Out:
#     state/ut                       literacy-group      Males   Females
# 0          0           Literate but below primary   78445099  68452498
# 1          0             Primary but below middle   99311072  84859761
# 2          0    Middle but below matric/secondary   77629578  56273688
# 3          0  Matric/Secondary but below graduate  116331881  75861463
# 4          0                   Graduate and above   42120460  26168511
# ..       ...                                  ...        ...       ...
# 175       35           Literate but below primary      22513     19616
# 176       35             Primary but below middle      37920     30495
# 177       35    Middle but below matric/secondary      39337     29283
# 178       35  Matric/Secondary but below graduate      47467     36607
# 179       35                   Graduate and above      13622     10537
#
# [180 rows x 4 columns]

# %%
languageDf = pd.read_excel('input/DDW-C19-0000.xlsx', names=['State Code','District','state/ut','TRU','literacy-group','Persons_L2','Males_L2','Females_L2','Persons_L3','Males_L3','Females_L3'])
languageDf = languageDf[languageDf['TRU']=='Total'].drop(['TRU'], axis=1)
languageDf = languageDf[(languageDf['literacy-group']!='Total') & (languageDf['literacy-group']!='Literate') & (languageDf['literacy-group']!='Illiterate')].drop(['District','Persons_L2','Persons_L3'], axis=1).reset_index(drop=True)
languageDf = languageDf.astype({'State Code':int})
languageDf
# Out:
#      State Code                   state/ut  \
# 0             0                      INDIA
# 1             0                      INDIA
# 2             0                      INDIA
# 3             0                      INDIA
# 4             0                      INDIA
# ..          ...                        ...
# 175          35  ANDAMAN & NICOBAR ISLANDS
# 176          35  ANDAMAN & NICOBAR ISLANDS
# 177          35  ANDAMAN & NICOBAR ISLANDS
# 178          35  ANDAMAN & NICOBAR ISLANDS
# 179          35  ANDAMAN & NICOBAR ISLANDS
#
#                           literacy-group  Males_L2 Females_L2  Males_L3  \
# 0             Literate but below primary  16126959   13218145   2108024
# 1               Primary but below middle  26588496   21982048   4782211
# 2      Middle but below matric/secondary  25214857   17901804   6266289
# 3    Matric/Secondary but below graduate  56022449   37181626  20411147
# 4                     Graduate and above  28285620   18672429  13316422
# ..                                   ...       ...        ...       ...
# 175           Literate but below primary     15471      12785      1936
# 176             Primary but below middle     29491      22946      4836
# 177    Middle but below matric/secondary     31737      23203      8315
# 178  Matric/Secondary but below graduate     40105      30799     17637
# 179                   Graduate and above     12380       9393      7817
#
#     Females_L3
# 0      1625592
# 1      3854085
# 2      4477061
# 3     13488072
# 4      8830121
# ..         ...
# 175       1631
# 176       3734
# 177       5679
# 178      13080
# 179       5518
#
# [180 rows x 7 columns]

# %%
languageDf['only1langM'] = pDf['Males'] - languageDf['Males_L2']
languageDf['only1langF'] = pDf['Females'] - languageDf['Females_L2']

languageDf['exact2langM'] = languageDf['Males_L2'] - languageDf['Males_L3']
languageDf['exact2langF'] = languageDf['Females_L2'] - languageDf['Females_L3']

languageDf['lang3ormoreM'] = languageDf['Males_L3']
languageDf['lang3ormoreF'] = languageDf['Females_L3']

languageDf['ratioL1M'] = languageDf['only1langM']/pDf['Males']
languageDf['ratioL1F'] = languageDf['only1langF']/pDf['Females']
languageDf['ratioL2M'] = languageDf['exact2langM']/pDf['Males']
languageDf['ratioL2F'] = languageDf['exact2langF']/pDf['Females']
languageDf['ratioL3M'] = languageDf['lang3ormoreM']/pDf['Males']
languageDf['ratioL3F'] = languageDf['lang3ormoreF']/pDf['Females']

languageDf
# Out:
#      State Code                   state/ut  \
# 0             0                      INDIA
# 1             0                      INDIA
# 2             0                      INDIA
# 3             0                      INDIA
# 4             0                      INDIA
# ..          ...                        ...
# 175          35  ANDAMAN & NICOBAR ISLANDS
# 176          35  ANDAMAN & NICOBAR ISLANDS
# 177          35  ANDAMAN & NICOBAR ISLANDS
# 178          35  ANDAMAN & NICOBAR ISLANDS
# 179          35  ANDAMAN & NICOBAR ISLANDS
#
#                           literacy-group  Males_L2 Females_L2  Males_L3  \
# 0             Literate but below primary  16126959   13218145   2108024
# 1               Primary but below middle  26588496   21982048   4782211
# 2      Middle but below matric/secondary  25214857   17901804   6266289
# 3    Matric/Secondary but below graduate  56022449   37181626  20411147
# 4                     Graduate and above  28285620   18672429  13316422
# ..                                   ...       ...        ...       ...
# 175           Literate but below primary     15471      12785      1936
# 176             Primary but below middle     29491      22946      4836
# 177    Middle but below matric/secondary     31737      23203      8315
# 178  Matric/Secondary but below graduate     40105      30799     17637
# 179                   Graduate and above     12380       9393      7817
#
#     Females_L3 only1langM only1langF exact2langM exact2langF lang3ormoreM  \
# 0      1625592   62318140   55234353    14018935    11592553      2108024
# 1      3854085   72722576   62877713    21806285    18127963      4782211
# 2      4477061   52414721   38371884    18948568    13424743      6266289
# 3     13488072   60309432   38679837    35611302    23693554     20411147
# 4      8830121   13834840    7496082    14969198     9842308     13316422
# ..         ...        ...        ...         ...         ...          ...
# 175       1631       7042       6831       13535       11154         1936
# 176       3734       8429       7549       24655       19212         4836
# 177       5679       7600       6080       23422       17524         8315
# 178      13080       7362       5808       22468       17719        17637
# 179       5518       1242       1144        4563        3875         7817
#
#     lang3ormoreF  ratioL1M  ratioL1F  ratioL2M  ratioL2F  ratioL3M  ratioL3F
# 0        1625592  0.794417    0.8069   0.17871  0.169352  0.026873  0.023748
# 1        3854085  0.732271   0.74096  0.219576  0.213623  0.048154  0.045417
# 2        4477061   0.67519   0.68188   0.24409  0.238562   0.08072  0.079559
# 3       13488072  0.518426  0.509875  0.306118  0.312327  0.175456  0.177799
# 4        8830121  0.328459  0.286454   0.35539  0.376113  0.316151  0.337433
# ..           ...       ...       ...       ...       ...       ...       ...
# 175         1631  0.312797  0.348236  0.601208  0.568617  0.085995  0.083146
# 176         3734  0.222284  0.247549  0.650185  0.630005  0.127532  0.122446
# 177         5679  0.193202  0.207629  0.595419  0.598436  0.211379  0.193935
# 178        13080  0.155097  0.158658  0.473339  0.484033  0.371563  0.357309
# 179         5518  0.091176   0.10857  0.334973  0.367752  0.573851  0.523678
#
# [180 rows x 19 columns]

# %%
literacyIndiaL3Df = pd.DataFrame(columns=['state/ut','literacy-group-males','ratio-males','literacy-group-females','ratio-females'])
for stCode in range(36):
    stDf = languageDf[languageDf['State Code'] == stCode].reset_index(drop=True)
    stMDf = stDf.sort_values(by=['ratioL3M'], ascending=False).reset_index(drop=True)
    stMDf = stMDf.head(1)
    stFDf = stDf.sort_values(by=['ratioL3F'], ascending=False).reset_index(drop=True)
    stFDf = stFDf.head(1)
    literacyIndiaL3Df.loc[len(literacyIndiaL3Df.index)] = [stCode,stMDf.iloc[0]['literacy-group'],stMDf.iloc[0]['ratioL3M'],stFDf.iloc[0]['literacy-group'],stFDf.iloc[0]['ratioL3F']]

literacyIndiaL3Df
# Out:
#    state/ut literacy-group-males  ratio-males literacy-group-females  \
# 0         0   Graduate and above     0.316151     Graduate and above
# 1         1   Graduate and above     0.669791     Graduate and above
# 2         2   Graduate and above     0.152538     Graduate and above
# 3         3   Graduate and above     0.767517     Graduate and above
# 4         4   Graduate and above     0.685636     Graduate and above
# 5         5   Graduate and above     0.071985     Graduate and above
# 6         6   Graduate and above     0.169245     Graduate and above
# 7         7   Graduate and above     0.232764     Graduate and above
# 8         8   Graduate and above     0.076426     Graduate and above
# 9         9   Graduate and above     0.064937     Graduate and above
# 10       10   Graduate and above     0.085916     Graduate and above
# 11       11   Graduate and above     0.760498     Graduate and above
# 12       12   Graduate and above     0.714686     Graduate and above
# 13       13   Graduate and above     0.707863     Graduate and above
# 14       14   Graduate and above     0.663693     Graduate and above
# 15       15   Graduate and above     0.276086     Graduate and above
# 16       16   Graduate and above     0.351565     Graduate and above
# 17       17   Graduate and above     0.507180     Graduate and above
# 18       18   Graduate and above     0.638794     Graduate and above
# 19       19   Graduate and above     0.244607     Graduate and above
# 20       20   Graduate and above     0.193147     Graduate and above
# 21       21   Graduate and above     0.673253     Graduate and above
# 22       22   Graduate and above     0.098255     Graduate and above
# 23       23   Graduate and above     0.108597     Graduate and above
# 24       24   Graduate and above     0.700751     Graduate and above
# 25       25   Graduate and above     0.532344     Graduate and above
# 26       26   Graduate and above     0.502658     Graduate and above
# 27       27   Graduate and above     0.642005     Graduate and above
# 28       28   Graduate and above     0.375135     Graduate and above
# 29       29   Graduate and above     0.481490     Graduate and above
# 30       30   Graduate and above     0.805702     Graduate and above
# 31       31   Graduate and above     0.709191     Graduate and above
# 32       32   Graduate and above     0.429095     Graduate and above
# 33       33   Graduate and above     0.153287     Graduate and above
# 34       34   Graduate and above     0.217898     Graduate and above
# 35       35   Graduate and above     0.573851     Graduate and above
#
#     ratio-females
# 0        0.337433
# 1        0.680314
# 2        0.152457
# 3        0.765537
# 4        0.705212
# 5        0.073002
# 6        0.196280
# 7        0.247149
# 8        0.086324
# 9        0.069244
# 10       0.084491
# 11       0.791838
# 12       0.716931
# 13       0.695980
# 14       0.621187
# 15       0.209615
# 16       0.313940
# 17       0.429673
# 18       0.600356
# 19       0.244835
# 20       0.217443
# 21       0.655997
# 22       0.129118
# 23       0.117693
# 24       0.670003
# 25       0.579392
# 26       0.548726
# 27       0.656895
# 28       0.362510
# 29       0.501979
# 30       0.804937
# 31       0.610190
# 32       0.353019
# 33       0.145446
# 34       0.204870
# 35       0.523678

# %%
literacyIndiaL2Df = pd.DataFrame(columns=['state/ut','literacy-group-males','ratio-males','literacy-group-females','ratio-females'])
for stCode in range(36):
    stDf = languageDf[languageDf['State Code'] == stCode].reset_index(drop=True)
    stMDf = stDf.sort_values(by=['ratioL2M'], ascending=False).reset_index(drop=True)
    stMDf = stMDf.head(1)
    stFDf = stDf.sort_values(by=['ratioL2F'], ascending=False).reset_index(drop=True)
    stFDf = stFDf.head(1)
    literacyIndiaL2Df.loc[len(literacyIndiaL2Df.index)] = [stCode,stMDf.iloc[0]['literacy-group'],stMDf.iloc[0]['ratioL2M'],stFDf.iloc[0]['literacy-group'],stFDf.iloc[0]['ratioL2F']]

literacyIndiaL2Df
# Out:
#    state/ut                 literacy-group-males  ratio-males  \
# 0         0                   Graduate and above     0.355390
# 1         1    Middle but below matric/secondary     0.594151
# 2         2                   Graduate and above     0.219609
# 3         3    Middle but below matric/secondary     0.337453
# 4         4  Matric/Secondary but below graduate     0.329628
# 5         5                   Graduate and above     0.343732
# 6         6                   Graduate and above     0.442299
# 7         7                   Graduate and above     0.634521
# 8         8                   Graduate and above     0.292334
# 9         9                   Graduate and above     0.403103
# 10       10                   Graduate and above     0.277969
# 11       11             Primary but below middle     0.471962
# 12       12           Literate but below primary     0.501836
# 13       13             Primary but below middle     0.492079
# 14       14    Middle but below matric/secondary     0.380605
# 15       15                   Graduate and above     0.614996
# 16       16  Matric/Secondary but below graduate     0.400483
# 17       17  Matric/Secondary but below graduate     0.400086
# 18       18             Primary but below middle     0.405712
# 19       19                   Graduate and above     0.352890
# 20       20                   Graduate and above     0.353659
# 21       21    Middle but below matric/secondary     0.294310
# 22       22                   Graduate and above     0.228917
# 23       23                   Graduate and above     0.392929
# 24       24    Middle but below matric/secondary     0.544774
# 25       25  Matric/Secondary but below graduate     0.416683
# 26       26           Literate but below primary     0.508823
# 27       27    Middle but below matric/secondary     0.511579
# 28       28                   Graduate and above     0.368235
# 29       29  Matric/Secondary but below graduate     0.325712
# 30       30           Literate but below primary     0.475980
# 31       31  Matric/Secondary but below graduate     0.236254
# 32       32                   Graduate and above     0.378123
# 33       33                   Graduate and above     0.597716
# 34       34                   Graduate and above     0.635704
# 35       35             Primary but below middle     0.650185
#
#                  literacy-group-females  ratio-females
# 0                    Graduate and above       0.376113
# 1     Middle but below matric/secondary       0.583226
# 2                    Graduate and above       0.240272
# 3     Middle but below matric/secondary       0.337852
# 4     Middle but below matric/secondary       0.353068
# 5                    Graduate and above       0.354939
# 6                    Graduate and above       0.472862
# 7                    Graduate and above       0.632253
# 8                    Graduate and above       0.362975
# 9                    Graduate and above       0.433187
# 10                   Graduate and above       0.311809
# 11             Primary but below middle       0.447626
# 12           Literate but below primary       0.513165
# 13             Primary but below middle       0.518272
# 14  Matric/Secondary but below graduate       0.367819
# 15                   Graduate and above       0.675127
# 16                   Graduate and above       0.365270
# 17                   Graduate and above       0.462337
# 18             Primary but below middle       0.389562
# 19                   Graduate and above       0.356559
# 20                   Graduate and above       0.399280
# 21  Matric/Secondary but below graduate       0.282474
# 22                   Graduate and above       0.295320
# 23                   Graduate and above       0.429425
# 24    Middle but below matric/secondary       0.537277
# 25    Middle but below matric/secondary       0.550489
# 26           Literate but below primary       0.546523
# 27    Middle but below matric/secondary       0.494496
# 28                   Graduate and above       0.376179
# 29  Matric/Secondary but below graduate       0.326569
# 30           Literate but below primary       0.492154
# 31                   Graduate and above       0.257109
# 32                   Graduate and above       0.388279
# 33                   Graduate and above       0.604541
# 34                   Graduate and above       0.637281
# 35             Primary but below middle       0.630005

# %%
literacyIndiaL1Df = pd.DataFrame(columns=['state/ut','literacy-group-males','ratio-males','literacy-group-females','ratio-females'])
for stCode in range(36):
    stDf = languageDf[languageDf['State Code'] == stCode].reset_index(drop=True)
    stMDf = stDf.sort_values(by=['ratioL1M'], ascending=False).reset_index(drop=True)
    stMDf = stMDf.head(1)
    stFDf = stDf.sort_values(by=['ratioL1F'], ascending=False).reset_index(drop=True)
    stFDf = stFDf.head(1)
    literacyIndiaL1Df.loc[len(literacyIndiaL1Df.index)] = [stCode,stMDf.iloc[0]['literacy-group'],stMDf.iloc[0]['ratioL1M'],stFDf.iloc[0]['literacy-group'],stFDf.iloc[0]['ratioL1F']]

literacyIndiaL1Df
# Out:
#    state/ut               literacy-group-males  ratio-males  \
# 0         0         Literate but below primary     0.794417
# 1         1         Literate but below primary     0.415514
# 2         2         Literate but below primary     0.821072
# 3         3         Literate but below primary     0.666601
# 4         4         Literate but below primary     0.610201
# 5         5         Literate but below primary     0.837642
# 6         6         Literate but below primary     0.843572
# 7         7         Literate but below primary     0.765633
# 8         8         Literate but below primary     0.892515
# 9         9         Literate but below primary     0.916881
# 10       10         Literate but below primary     0.790880
# 11       11         Literate but below primary     0.392646
# 12       12         Literate but below primary     0.182052
# 13       13         Literate but below primary     0.351607
# 14       14         Literate but below primary     0.625026
# 15       15         Literate but below primary     0.769271
# 16       16         Literate but below primary     0.672761
# 17       17         Literate but below primary     0.799053
# 18       18         Literate but below primary     0.527125
# 19       19         Literate but below primary     0.887017
# 20       20         Literate but below primary     0.649459
# 21       21         Literate but below primary     0.787428
# 22       22         Literate but below primary     0.863643
# 23       23           Primary but below middle     0.880123
# 24       24         Literate but below primary     0.782293
# 25       25         Literate but below primary     0.631816
# 26       26  Middle but below matric/secondary     0.368514
# 27       27         Literate but below primary     0.623575
# 28       28         Literate but below primary     0.816320
# 29       29         Literate but below primary     0.646575
# 30       30         Literate but below primary     0.198579
# 31       31         Literate but below primary     0.894539
# 32       32         Literate but below primary     0.900143
# 33       33         Literate but below primary     0.811405
# 34       34         Literate but below primary     0.853306
# 35       35         Literate but below primary     0.312797
#
#                literacy-group-females  ratio-females
# 0          Literate but below primary       0.806900
# 1          Literate but below primary       0.433885
# 2          Literate but below primary       0.834849
# 3          Literate but below primary       0.669270
# 4          Literate but below primary       0.608200
# 5            Primary but below middle       0.852406
# 6          Literate but below primary       0.850880
# 7          Literate but below primary       0.769320
# 8          Literate but below primary       0.898670
# 9          Literate but below primary       0.914209
# 10  Middle but below matric/secondary       0.796260
# 11         Literate but below primary       0.426115
# 12         Literate but below primary       0.186749
# 13         Literate but below primary       0.379519
# 14         Literate but below primary       0.628061
# 15         Literate but below primary       0.827003
# 16         Literate but below primary       0.708909
# 17         Literate but below primary       0.831964
# 18         Literate but below primary       0.583955
# 19         Literate but below primary       0.909949
# 20         Literate but below primary       0.658212
# 21         Literate but below primary       0.810188
# 22         Literate but below primary       0.867966
# 23         Literate but below primary       0.881282
# 24         Literate but below primary       0.798674
# 25         Literate but below primary       0.621291
# 26         Literate but below primary       0.309617
# 27         Literate but below primary       0.652025
# 28         Literate but below primary       0.833329
# 29         Literate but below primary       0.656461
# 30         Literate but below primary       0.203574
# 31         Literate but below primary       0.928381
# 32         Literate but below primary       0.927691
# 33         Literate but below primary       0.818735
# 34         Literate but below primary       0.868128
# 35         Literate but below primary       0.348236

# %%
literacyIndiaL3Df.to_csv('literacy-gender-a.csv',index=False)
literacyIndiaL2Df.to_csv('literacy-gender-b.csv',index=False)
literacyIndiaL1Df.to_csv('literacy-gender-c.csv',index=False)
